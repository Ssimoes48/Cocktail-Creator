# %%
import pandas as pd

csv_path = "Data/mr_boston_flattened.csv"

cocktail_df = pd.read_csv(csv_path, encoding="utf-8")
cocktail_df
# Out:
#                      name               category measurement-1  \
# 0                 Gauguin      Cocktail Classics          2 oz
# 1         Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2               Apple Pie  Cordials and Liqueurs          3 oz
# 3    Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4             Cool Carlos      Cocktail Classics      1 1/2 oz
# ..                    ...                    ...           ...
# 985  Wallis Blue Cocktail                    Gin             1
# 986    Minnehaha Cocktail      Cocktail Classics        1/4 oz
# 987      Wallick Cocktail                    Gin      1 1/2 oz
# 988   Waikiki Beachcomber                    Gin        3/4 oz
# 989        Vow Of Silence                    Gin      1 1/2 oz
#
#                     ingredient-1 measurement-2          ingredient-2  \
# 0                      Light Rum          1 oz   Passion Fruit Syrup
# ...

# %%
cocktail_df["measurement-1"] = cocktail_df["measurement-1"].str.strip(" oz")


cocktail_df
# Out:
#                      name               category measurement-1  \
# 0                 Gauguin      Cocktail Classics             2
# 1         Fort Lauderdale      Cocktail Classics         1 1/2
# 2               Apple Pie  Cordials and Liqueurs             3
# 3    Cuban Cocktail No. 1      Cocktail Classics           1/2
# 4             Cool Carlos      Cocktail Classics         1 1/2
# ..                    ...                    ...           ...
# 985  Wallis Blue Cocktail                    Gin             1
# 986    Minnehaha Cocktail      Cocktail Classics           1/4
# 987      Wallick Cocktail                    Gin         1 1/2
# 988   Waikiki Beachcomber                    Gin           3/4
# 989        Vow Of Silence                    Gin         1 1/2
#
#                     ingredient-1 measurement-2          ingredient-2  \
# 0                      Light Rum          1 oz   Passion Fruit Syrup
# ...
