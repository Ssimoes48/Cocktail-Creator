# %%
import pandas as pd

# %%
filepath1 = "Data/statelatlong.csv"

state_df = pd.read_csv(filepath1)


state_df.head()
# Out:
#   abbr   latitude   longitude       state
# 0   AL  32.601011  -86.680736     Alabama
# 1   AK  61.302501 -158.775020      Alaska
# 2   AZ  34.168219 -111.930907     Arizona
# 3   AR  34.751928  -92.131378    Arkansas
# 4   CA  37.271875 -119.270415  California

# %%
filepath2 = "Data/state_cocktail.csv"

cocktail_df = pd.read_csv(filepath2)

cocktail_df.head()
# Out:
#         state          cocktail
# 0     Alabama         Hurricane
# 1      Alaska      Whiskey Sour
# 2     Arizona            Paloma
# 3    Arkansas   Frozen Daiquiri
# 4  California            Paloma

# %%
combined_df = pd.merge(state_df, cocktail_df, on="state")
coombined_df['']

combined_df
# Out:
#    abbr   latitude   longitude                 state             cocktail
# 0    AL  32.601011  -86.680736               Alabama            Hurricane
# 1    AK  61.302501 -158.775020                Alaska         Whiskey Sour
# 2    AZ  34.168219 -111.930907               Arizona               Paloma
# 3    AR  34.751928  -92.131378              Arkansas      Frozen Daiquiri
# 4    CA  37.271875 -119.270415            California               Paloma
# 5    CO  38.997934 -105.550567              Colorado            Hurricane
# 6    CT  41.518784  -72.757507           Connecticut            Margarita
# 7    DE  39.145251  -75.418921              Delaware          Screwdriver
# 8    DC  38.899349  -77.014567  District of Columbia       Old Fashioned
# 9    FL  27.975728  -83.833017               Florida           Cuba Libre
# 10   GA  32.678125  -83.222976               Georgia              Sazerac
# 11   HI  20.460000 -157.505000                Hawaii   Lemon Drop Martini
# 12   ID  45.494576 -114.142430                 Idaho             Kamikaze
# 13   IL  39.739318  -89.504139              Illinois            Manhattan
# 14   IN  39.766219  -86.441277               Indiana            French 75
# 15   IA  41.938317  -93.389798                  Iowa             Kamikaze
# 16   KS  38.498779  -98.320078                Kansas          Screwdriver
# 17   KY  37.822294  -85.768240              Kentucky                 Lily
# 18   LA  30.973377  -91.429910             Louisiana           Bushwacker
# 19   ME  45.218513  -69.014866                 Maine            Margarita
# 20   MD  38.806352  -77.268416              Maryland             Kamikaze
# 21   MA  42.062940  -71.718067         Massachusetts        Old Fashioned
# 22   MI  44.943560  -86.415805              Michigan                Cosmo
# 23   MN  46.441859  -93.365515             Minnesota             Oliveto
# 24   MS  32.585106  -89.877220           Mississippi           Painkiller
# 25   MO  38.304662  -92.437099              Missouri       Gin and Tonic
# 26   MT  46.679800 -110.044783               Montana       Blue Hawaiian
# 27   NE  41.500819  -99.680902              Nebraska        Old Fashioned
# 28   NV  38.502032 -117.023060                Nevada          Grasshopper
# 29   NH  44.001231  -71.579923         New Hampshire        Old Fashioned
# 30   NJ  40.143006  -74.731116            New Jersey            Manhattan
# 31   NM  34.166232 -106.026069            New Mexico        Old Fashioned
# 32   NY  40.705626  -73.979680              New York            Manhattan
# 33   NC  35.214563  -79.891267        North Carolina           Bushwacker
# 34   ND  47.467882 -100.302266          North Dakota             Kamikaze
# 35   OH  40.190362  -82.669252                  Ohio         Boulevardier
# 36   OK  35.309765  -98.716558              Oklahoma        Black Russian
# 37   OR  44.141905 -120.538099                Oregon        Old Fashioned
# 38   PA  40.994593  -77.604698          Pennsylvania        Whiskey Sour
# 39   RI  41.582728  -71.506451          Rhode Island               Cosmo
# 40   SC  33.625050  -80.947038        South Carolina      Tequila Sunrise
# 41   SD  44.212699 -100.247164          South Dakota          Screwdriver
# 42   TN  35.830521  -85.978599             Tennessee          Buschwacker
# 43   TX  31.169336 -100.076842                 Texas               Paloma
# 44   UT  39.499761 -111.547028                  Utah             Cape Cod
# 45   VT  43.871755  -72.447783               Vermont         Cosmopolitan
# 46   VA  38.003386  -79.458786              Virginia        Old Fashioned
# 47   WA  38.899349  -77.014567            Washington        Old Fashioned
# 48   WV  38.920171  -80.181691         West Virginia             Kamikaze
# 49   WI  44.786297  -89.826705             Wisconsin          Grasshopper
# 50   WY  43.000325 -107.554567               Wyoming        White Russian

# %%
combined_df.to_csv("Data/combined_state.csv", encoding="utf-8", index=False, header=True)
combined_df
# Out:
#    abbr   latitude   longitude                 state             cocktail
# 0    AL  32.601011  -86.680736               Alabama            Hurricane
# 1    AK  61.302501 -158.775020                Alaska         Whiskey Sour
# 2    AZ  34.168219 -111.930907               Arizona               Paloma
# 3    AR  34.751928  -92.131378              Arkansas      Frozen Daiquiri
# 4    CA  37.271875 -119.270415            California               Paloma
# 5    CO  38.997934 -105.550567              Colorado            Hurricane
# 6    CT  41.518784  -72.757507           Connecticut            Margarita
# 7    DE  39.145251  -75.418921              Delaware          Screwdriver
# 8    DC  38.899349  -77.014567  District of Columbia       Old Fashioned
# 9    FL  27.975728  -83.833017               Florida           Cuba Libre
# 10   GA  32.678125  -83.222976               Georgia              Sazerac
# 11   HI  20.460000 -157.505000                Hawaii   Lemon Drop Martini
# 12   ID  45.494576 -114.142430                 Idaho             Kamikaze
# 13   IL  39.739318  -89.504139              Illinois            Manhattan
# 14   IN  39.766219  -86.441277               Indiana            French 75
# 15   IA  41.938317  -93.389798                  Iowa             Kamikaze
# 16   KS  38.498779  -98.320078                Kansas          Screwdriver
# 17   KY  37.822294  -85.768240              Kentucky                 Lily
# 18   LA  30.973377  -91.429910             Louisiana           Bushwacker
# 19   ME  45.218513  -69.014866                 Maine            Margarita
# 20   MD  38.806352  -77.268416              Maryland             Kamikaze
# 21   MA  42.062940  -71.718067         Massachusetts        Old Fashioned
# 22   MI  44.943560  -86.415805              Michigan                Cosmo
# 23   MN  46.441859  -93.365515             Minnesota             Oliveto
# 24   MS  32.585106  -89.877220           Mississippi           Painkiller
# 25   MO  38.304662  -92.437099              Missouri       Gin and Tonic
# 26   MT  46.679800 -110.044783               Montana       Blue Hawaiian
# 27   NE  41.500819  -99.680902              Nebraska        Old Fashioned
# 28   NV  38.502032 -117.023060                Nevada          Grasshopper
# 29   NH  44.001231  -71.579923         New Hampshire        Old Fashioned
# 30   NJ  40.143006  -74.731116            New Jersey            Manhattan
# 31   NM  34.166232 -106.026069            New Mexico        Old Fashioned
# 32   NY  40.705626  -73.979680              New York            Manhattan
# 33   NC  35.214563  -79.891267        North Carolina           Bushwacker
# 34   ND  47.467882 -100.302266          North Dakota             Kamikaze
# 35   OH  40.190362  -82.669252                  Ohio         Boulevardier
# 36   OK  35.309765  -98.716558              Oklahoma        Black Russian
# 37   OR  44.141905 -120.538099                Oregon        Old Fashioned
# 38   PA  40.994593  -77.604698          Pennsylvania        Whiskey Sour
# 39   RI  41.582728  -71.506451          Rhode Island               Cosmo
# 40   SC  33.625050  -80.947038        South Carolina      Tequila Sunrise
# 41   SD  44.212699 -100.247164          South Dakota          Screwdriver
# 42   TN  35.830521  -85.978599             Tennessee          Buschwacker
# 43   TX  31.169336 -100.076842                 Texas               Paloma
# 44   UT  39.499761 -111.547028                  Utah             Cape Cod
# 45   VT  43.871755  -72.447783               Vermont         Cosmopolitan
# 46   VA  38.003386  -79.458786              Virginia        Old Fashioned
# 47   WA  38.899349  -77.014567            Washington        Old Fashioned
# 48   WV  38.920171  -80.181691         West Virginia             Kamikaze
# 49   WI  44.786297  -89.826705             Wisconsin          Grasshopper
# 50   WY  43.000325 -107.554567               Wyoming        White Russian

# %%
# Out:
#    abbr   latitude   longitude                 state             cocktail
# 0    AL  32.601011  -86.680736               Alabama            Hurricane
# 1    AK  61.302501 -158.775020                Alaska         Whiskey Sour
# 2    AZ  34.168219 -111.930907               Arizona               Paloma
# 3    AR  34.751928  -92.131378              Arkansas      Frozen Daiquiri
# 4    CA  37.271875 -119.270415            California               Paloma
# 5    CO  38.997934 -105.550567              Colorado            Hurricane
# 6    CT  41.518784  -72.757507           Connecticut            Margarita
# 7    DE  39.145251  -75.418921              Delaware          Screwdriver
# 8    DC  38.899349  -77.014567  District of Columbia       Old Fashioned
# 9    FL  27.975728  -83.833017               Florida           Cuba Libre
# 10   GA  32.678125  -83.222976               Georgia              Sazerac
# 11   HI  20.460000 -157.505000                Hawaii   Lemon Drop Martini
# 12   ID  45.494576 -114.142430                 Idaho             Kamikaze
# 13   IL  39.739318  -89.504139              Illinois            Manhattan
# 14   IN  39.766219  -86.441277               Indiana            French 75
# 15   IA  41.938317  -93.389798                  Iowa             Kamikaze
# 16   KS  38.498779  -98.320078                Kansas          Screwdriver
# 17   KY  37.822294  -85.768240              Kentucky                 Lily
# 18   LA  30.973377  -91.429910             Louisiana           Bushwacker
# 19   ME  45.218513  -69.014866                 Maine            Margarita
# 20   MD  38.806352  -77.268416              Maryland             Kamikaze
# 21   MA  42.062940  -71.718067         Massachusetts        Old Fashioned
# 22   MI  44.943560  -86.415805              Michigan                Cosmo
# 23   MN  46.441859  -93.365515             Minnesota             Oliveto
# 24   MS  32.585106  -89.877220           Mississippi           Painkiller
# 25   MO  38.304662  -92.437099              Missouri       Gin and Tonic
# 26   MT  46.679800 -110.044783               Montana       Blue Hawaiian
# 27   NE  41.500819  -99.680902              Nebraska        Old Fashioned
# 28   NV  38.502032 -117.023060                Nevada          Grasshopper
# 29   NH  44.001231  -71.579923         New Hampshire        Old Fashioned
# 30   NJ  40.143006  -74.731116            New Jersey            Manhattan
# 31   NM  34.166232 -106.026069            New Mexico        Old Fashioned
# 32   NY  40.705626  -73.979680              New York            Manhattan
# 33   NC  35.214563  -79.891267        North Carolina           Bushwacker
# 34   ND  47.467882 -100.302266          North Dakota             Kamikaze
# 35   OH  40.190362  -82.669252                  Ohio         Boulevardier
# 36   OK  35.309765  -98.716558              Oklahoma        Black Russian
# 37   OR  44.141905 -120.538099                Oregon        Old Fashioned
# 38   PA  40.994593  -77.604698          Pennsylvania        Whiskey Sour
# 39   RI  41.582728  -71.506451          Rhode Island               Cosmo
# 40   SC  33.625050  -80.947038        South Carolina      Tequila Sunrise
# 41   SD  44.212699 -100.247164          South Dakota          Screwdriver
# 42   TN  35.830521  -85.978599             Tennessee          Buschwacker
# 43   TX  31.169336 -100.076842                 Texas               Paloma
# 44   UT  39.499761 -111.547028                  Utah             Cape Cod
# 45   VT  43.871755  -72.447783               Vermont         Cosmopolitan
# 46   VA  38.003386  -79.458786              Virginia        Old Fashioned
# 47   WA  38.899349  -77.014567            Washington        Old Fashioned
# 48   WV  38.920171  -80.181691         West Virginia             Kamikaze
# 49   WI  44.786297  -89.826705             Wisconsin          Grasshopper
# 50   WY  43.000325 -107.554567               Wyoming        White Russian

# %%
from sqlalchemy import create_engine
from config import postgres_pwd, postgres_user

db_name = "cocktail_db"
table_name = "state"

connection_string = f"{postgres_user}:{postgres_pwd}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')
conn = engine.connect()

final_df.to_sql(table_name, con=engine, if_exists="append", index=False)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# ForeignKeyViolation: insert or update on table "state" violates foreign key constraint "fk_state_cocktail"
# DETAIL:  Key (cocktail)=( Hurricane) is not present in table "cocktail".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-11-4ed57f952cc0> in <module>
#       9 conn = engine.connect()
#      10
# ---> 11 final_df.to_sql(table_name, con=engine, if_exists="append", index=False)
#      12
#      13 conn.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2600         from pandas.io import sql
#    2601
# -> 2602         sql.to_sql(
#    2603             self,
#    2604             name,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "state" violates foreign key constraint "fk_state_cocktail"
# DETAIL:  Key (cocktail)=( Hurricane) is not present in table "cocktail".
#
# [SQL: INSERT INTO state (abbr, latitude, longitude, state, cocktail) VALUES (%(abbr)s, %(latitude)s, %(longitude)s, %(state)s, %(cocktail)s)]
# [parameters: ({'abbr': 'AL', 'latitude': 32.601011199999995, 'longitude': -86.6807365, 'state': 'Alabama', 'cocktail': ' Hurricane'}, {'abbr': 'AK', 'latitude': 61.3025006, 'longitude': -158.7750198, 'state': 'Alaska', 'cocktail': ' Whiskey Sour'}, {'abbr': 'AZ', 'latitude': 34.1682185, 'longitude': -111.930907, 'state': 'Arizona', 'cocktail': ' Paloma'}, {'abbr': 'AR', 'latitude': 34.7519275, 'longitude': -92.13137840000002, 'state': 'Arkansas', 'cocktail': ' Frozen Daiquiri'}, {'abbr': 'CA', 'latitude': 37.2718745, 'longitude': -119.2704153, 'state': 'California', 'cocktail': ' Paloma'}, {'abbr': 'CO', 'latitude': 38.9979339, 'longitude': -105.55056699999999, 'state': 'Colorado', 'cocktail': ' Hurricane'}, {'abbr': 'CT', 'latitude': 41.518783500000005, 'longitude': -72.75750699999999, 'state': 'Connecticut', 'cocktail': ' Margarita'}, {'abbr': 'DE', 'latitude': 39.145251, 'longitude': -75.41892059999999, 'state': 'Delaware', 'cocktail': ' Screwdriver'}  ... displaying 10 of 51 total bound parameter sets ...  {'abbr': 'WI', 'latitude': 44.7862968, 'longitude': -89.82670490000001, 'state': 'Wisconsin', 'cocktail': ' Grasshopper'}, {'abbr': 'WY', 'latitude': 43.000325, 'longitude': -107.5545669, 'state': 'Wyoming', 'cocktail': ' White Russian'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
