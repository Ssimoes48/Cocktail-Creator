# %%
import pandas as pd
import numpy as np
from fractions import Fraction


csv_path = "Data/mr_boston_flattened.csv"

# %%
category_df = pd.read_csv(csv_path, encoding="utf-8")
category_df.head()
# Out:
#                    name               category measurement-1  \
# 0               Gauguin      Cocktail Classics          2 oz
# 1       Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2             Apple Pie  Cordials and Liqueurs          3 oz
# 3  Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4           Cool Carlos      Cocktail Classics      1 1/2 oz
#
#        ingredient-1 measurement-2          ingredient-2 measurement-3  \
# 0         Light Rum          1 oz   Passion Fruit Syrup          1 oz
# 1         Light Rum        1/2 oz        Sweet Vermouth        1/4 oz
# 2    Apple schnapps          1 oz     Cinnamon schnapps           NaN
# 3   Juice of a Lime        1/2 oz        Powdered Sugar          2 oz
# 4          Dark rum          2 oz       Cranberry Juice          2 oz
#
#        ingredient-3 measurement-4      ingredient-4 measurement-5  \
# 0       Lemon Juice          1 oz        Lime Juice           NaN
# ...

# %%
# drop columns from dataframe
type2_df = type_df = category_df[["name", "category"]]
type3_df = type2_df.rename(columns={'category':'type'})
type3_df.head()
# Out:
#                    name                   type
# 0               Gauguin      Cocktail Classics
# 1       Fort Lauderdale      Cocktail Classics
# 2             Apple Pie  Cordials and Liqueurs
# 3  Cuban Cocktail No. 1      Cocktail Classics
# 4           Cool Carlos      Cocktail Classics

# %% [markdown]
# ## load to table

# %%
from sqlalchemy import create_engine
from config import postgres_pwd, postgres_user

db_name = "cocktail_db"
table_name = "cocktails"

connection_string = f"{postgres_user}:{postgres_pwd}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')
conn = engine.connect()

final_list_df.to_sql(table_name, con=engine, if_exists="append", index=False)

conn.close()

# %%
# reading image source link from img-src csv
file2 = "Cocktail-Creator/Data/img-src.csv"

img_df = pd.read_csv(file2)

img_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8c0bc2e8739f> in <module>
#       2 file2 = "Cocktail-Creator/Data/img-src.csv"
#       3
# ----> 4 img_df = pd.read_csv(file2)
#       5
#       6 img_df.head()
#
# ...

# %%
# combine image source with category
combined_df = pd.merge(type_df, img_df, on="name")

combined_df

# %%
combined_df.to_csv("Cocktail-Creator/Data/combined_type_src.csv", encoding="utf-8", index=False, header=True)
